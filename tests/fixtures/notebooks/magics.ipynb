# %% [markdown]
# # Magics fixture

# %%
# %matplotlib inline
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler

# %%
# !pip install qiskit --quiet

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)

# %%
StatevectorSampler().run([qc])

# %%
# %%bash
# echo this is not python

# %%
after_bash = QuantumCircuit(1)
after_bash.measure_all()
StatevectorSampler().run([after_bash])

# %%
hidden = QuantumCircuit(1)
# %run prepare.py
StatevectorSampler().run([hidden])

# %%
# %%time
timed = QuantumCircuit(1)
StatevectorSampler().run([timed])
